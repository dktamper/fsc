# %% [markdown]
# # Module 1 Scientific Computing Basics

# %% [markdown]
# ## Activity
#
# 1. Why do you think understanding computer programs is relevant in our time today especially in the new normal?
#     * Since so much of our world is automated, computer programming is important today. The relationship between people and computers must be able to influence humans. We use computer programming to harness the computational power, because computers and machoines are able to do things so easily and accurately. In this time of new normal, I think the relevant of understanding computer program is that it helps us to train our brain to break every problem down to bits and understand it better. You start seeing issues in the light of solutions when study computer programs. After learning computer programs, when experiencing problem, you start envisionining potential ways to solve it. You could also predict any positive outcomes from it. However complicated the issue seem you are determined to act on it regardless. You turn yourself into an entity guided by the solition.
#
# 2. If you were be able to learn computer program what program will you code? Why?
#     * If i were be able to learn computer program, the program i will code is the artificial intelligence. Arteficial Intelligence is a class of computer programs that "learns" to matvh mathematical data models, meaning it attempts to fit. This is distinct category of software since its funcionality is not fully human-designed, but evolves on its own.
#
# 3. What would be your primary motivation in learning programming?
#
#       * As a beginner, my primary motivation in learning programming is choosing consistency over speed. I know learning programming isn't easy but little by little I will be a good coder as I learn. On the same note, the rather cliched saying, "slow and steady wins the race" is very true. This is why consistency is more important than trying to go as fast as I possibly can.

# %% [markdown]
# ## Application
#
# ### Ask yourself:
#    1. Why do you think Python is the most applicable programming language for scientific computing?
#
#        * I think Python is the most applicable programming language for scientific computing because it is great for prototyping (e.i. dynamic typing), flexible interaction with other languages, and manipulates string surprisingly well - natural language processing, artificial intellegence and big data, etc.
#
#    2. If Python	can	build anything,	where do you think Python is not applicable?
#
#        * One of Python's drawbacks is that it is not native to the mobile environment. Neither of the major mobile platforms - iOS and Android - support Python as an official programming language. One reason for that is the memory consumption. For any memory intensive tasks Python is not a good choice. That is why it is not used for that purpose.

# %% [markdown]
# ### Exercise 1: Mailing Address

# %%
def personal_details():
    name, age = "Dan Kevin Amper", 20
    address = " Purok 7, Bago Gallera, Davao City"
    print("Name: {}\nAge: {}\nAddress: {}".format(name, age, address))

personal_details()

# %% [markdown]
# ### Exercise 2: Area of a Room

# %%
width = float(input("please enter the height:"))
length = float(input("please enter the length:"))
area = width*length

# %% [markdown]
# ### Exercise 3: Arithmetic

# %%
import math

a = int(input("Enter first number: "))
b = int(input("Enter second number: "))

#Calculating and printing sum
print(a,"+",b,"=",a+b)

#Calculating and printing difference
print(a,"-",b,"=",a-b)

#Calculating and printing Quotient
print(a,"/",b,"=",a/b)

#Calculating and printing product
print(a,"*",b,"=",a*b)

#Calculating and printing remainder
print(a,"%",b,"=",a%b)

#Calculating and printing log10 a
print ("math.log10(a) : ", math.log10(a))

#Calculating and printing log10ab
print ("math.log10(ab) : ", math.log10(a)+ math.log10(b))

# %% [markdown]
# ### Exercise 4: Area and Volume

# %%
from math import pi
r = float(input ("Input the radius of the circle : "))
print ("The area of the circle with radius " + str(r) + " is: " + str(pi * r**2))
